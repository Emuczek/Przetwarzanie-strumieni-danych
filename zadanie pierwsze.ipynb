# %%
# import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
days = np.linspace(1, 31, 31)
temp_d = [np.random.normal(15, 5) for x in days]
temp_n = [np.random.normal(5, 5) for x in days]
dic = {"Dzień": days.astype(int), "Temperatura w dzień": temp_d, "Temperatura w nocy": temp_n}
df = pd.DataFrame(dic)

# %%
sns.barplot(data=df, x="Dzień", y="Temperatura w dzień", color="yellow")
sns.barplot(data=df, x="Dzień", y="Temperatura w nocy", color="blue")
# Out:
# <Axes: xlabel='Dzień', ylabel='Temperatura w nocy'>

# %%
sns.lineplot(data=df, x="Dzień", y="Temperatura w dzień", color="yellow")
sns.lineplot(data=df, x="Dzień", y="Temperatura w nocy", color="blue")
# Out:
# <Axes: xlabel='Dzień', ylabel='Temperatura w dzień'>
